# %%
#variables
first_name = 'paul'
first_name
# Out:
# 'paul'

# %%
#data type
male = True
type(male)
# Out:
# bool

# %%
# dictionary
staffs_in_ict = {'Paul':3, 'Yomi':1, 'Eunice':2, 'sam':3, 'dare':3, 'dave':2}

# %%
#function
print(staffs_in_ict)
# Out:
# {'Paul': 3, 'Yomi': 1, 'Eunice': 2, 'sam': 3, 'dare': 3, 'dave': 2}

# %%
# listing out data with the len function
len(staffs_in_ict)
# Out:
# 6

# %%
# estracting data
staffs_in_ict['Paul']
# Out:
# 3

# %%
# retrieving data with a key (. operation)

# %%
staffs_in_ict.keys()
# Out:
# dict_keys(['Paul', 'Yomi', 'Eunice', 'sam', 'dare', 'dave'])

# %%
staffs_in_ict.values()
# Out:
# dict_values([3, 1, 2, 3, 3, 2])

# %%
# updating data
staffs_in_ict.update({'sola':4})

# %%
staffs_in_ict
# Out:
# {'Paul': 3, 'Yomi': 1, 'Eunice': 2, 'sam': 3, 'dare': 3, 'dave': 2, 'sola': 4}

# %%
# if else | elif statements

# %%
x= int(input('enter_number:'))
if (x % 2 ==0):
    print('This is an even number')
else:
    print('This is an odd number')

# %%
# Looping

# %%
# Looping
x= 2
while(x<=6):
    print(x)
    x+= 1
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
# Break statements
correct_number= 5
while True:
    number= int(input('guess number:'))
    if (number == correct_number):
        print('correct')
        break
else:
    print ('wrong')
# Out:
# guess number: 7
# guess number: 8
# guess number: 4
# guess number: 5
# correct

# %%
i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1
# Out:
# 1
# 2
# 3

# %%
numbers = [1,2,3,4,10]
for x in numbers:
    print (x)
# Out:
# 1
# 2
# 3
# 4
# 10

# %%
for x in range(1,5):
    print (x)
# Out:
# 1
# 2
# 3
# 4

# %%
# indexing
y = [2,4,6,8,10]
[10,1,2,3,4]

y[3]
# Out:
# 8

# %%
# indexing - for sstrings
health_status = ['xyz','bp','pre','ecl','hyper']
[1,2,3,4,5]

health_status[2:5]
# Out:
# ['pre', 'ecl', 'hyper']

# %%
health_status.insert(2, 'ss')
print (health_status)
# Out:
# ['xyz', 'bp', 'ss', 'pre', 'ecl', 'hyper']
